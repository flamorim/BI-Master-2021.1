# %% [markdown]
# <a href="https://colab.research.google.com/github/flamorim/BI-Master-2021.1/blob/Features(versao-1)/aula01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("ola")
print("2")
print("tchau")
from google.colab import drive
drive.mount("/content/drive")

def valor_none(a,b,c=None):
   result = a + b
   return result

valor_none(1,2)

string_1 = "h\noje"
string_2 = '''dep
ois'''
string_3 = """Ho
je"""
type(string_1),type(string_2),type(string_3)
print(string_1)
print(string_2)
print(string_3)

# %%
set_1 = {'maca' , 'pera'}
print (set_1)
# Out:
# {'pera', 'maca'}

# %%
set_2 = {1,2,3,'maca'}
print (set_2)
# Out:
# {1, 2, 3, 'maca'}

# %%
a = 'oi'
b = 1
c = 1.5
print(f'isso é uma string: {a}.\nIsso é um número: {b}.\nIsso é um float: {c}.')
# Out:
# isso é uma string: oi.
# Isso é um número: 1.
# Isso é um float: 1.5.

# %%
a = input('forneca um numero: ')
print(2*int(a))
# Out:
# forneca um numero: 3
# 6

# %%
a = 11
b = 2
if a == 1:
  print("primeiro")
elif a == 2:
  print("segundo")  
elif a == 3:
  print("terceiro")
else: 
  print("nenhum")
# Out:
# nenhum

# %%
print("1")

# %% [markdown]
# teste
