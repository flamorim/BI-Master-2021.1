# %% [markdown]
# <a href="https://colab.research.google.com/github/flamorim/BI-Master-2021.1/blob/Features(versao-1)/Aula01_2021_03_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# exercicio 01

#variaveis
resultado = False

#funcoes
def soma(a,b):
   return a + b

def subtrai(a,b):
   return a - b

def divide(a,b):
   return a / b

def multiplica(a,b):
   return a * b

#Codigo principal2
num_1 = float(input("Favor entrar com o primeiro número: "))
num_2 = float(input("favor entrar com o segundo número: "))
#ope = input("Favor informar a operação desejada: ")

ope = None 
while ope not in {"soma", "divisão","multiplicação","subtração","q"}: 
         ope = input("Favor informar a operação desejada. Responda com 'soma', 'divisão','multiplicação','subtração' ou 'q' para sair: ")
         
if ope.lower() == "soma":
  resultado = soma(num_1,num_2)
elif ope.lower() == "divisão":
  resultado = divide(num_1,num_2)
elif ope.lower() == "multiplicação":
  resultado = multiplica(num_1,num_2)
elif ope.lower() == ("subtração"):
  resultado = subtrai(num_1,num_2)

if ope.lower() == ("q"):
  print("programa abortado")
elif resultado:
  print(f'O resultado é: {resultado}')
  # par ou impar somente para numeros inteiros  
  if (resultado // 1) == resultado:
    print("É um número inteiro")
    if (resultado % 2):
      print("É um número impar")
    else:
      print("É um número par")
  else:
    print("É um número decimal")
  if ( resultado < 0):
    print("É um número negativo")
  else:
    print("É um número positivo")
# Out:
# Favor entrar com o primeiro número: 2
# favor entrar com o segundo número: 2
# Favor informar a operação desejada. Responda com 'soma', 'divisão','multiplicação','subtração' ou 'q' para sair: Q
# Favor informar a operação desejada. Responda com 'soma', 'divisão','multiplicação','subtração' ou 'q' para sair: soma
# O resultado é: 4.0
# É um número inteiro
# É um número par
# É um número positivo

# %%
#Exercicio 02

#variaveis
resultado = 0

#funcoes
def classifica(num):
  if num < 2:
    return("Inocente")
  elif num < 3:
    return("Suspeita")
  elif num < 5:
    return("cumplice")
  elif num == 5:
    return("Assassino")
  return(False)

#programa principal
print("Favor responder com ´sim´ ou ´nao´")

resposta = False
while resposta not in {"sim", "não"}: 
  resposta = input("Telefonou para a vítima?")
if resposta.lower() == "sim":
  resultado += 1

resposta = False
while resposta not in {"sim", "não"}: 
  resposta = input("Esteve no local do crime?")
if resposta.lower() == "sim":
  resultado += 1

resposta = False
while resposta not in {"sim", "não"}: 
  resposta = input("Mora perto da vítima?")
if resposta.lower() == "sim":
  resultado += 1

resposta = False
while resposta not in {"sim", "não"}: 
  resposta = input("Devia para a vítima?")
if resposta.lower() == "sim":
  resultado += 1

resposta = False
while resposta not in {"sim", "não"}: 
  resposta = input("Já trabalhou com a vítima?")
if resposta.lower() == "sim":
  resultado += 1

print(f'Então vc é {classifica(resultado)}!')
print(resultado)
# Out:
# Favor responder com ´sim´ ou ´nao´
# Telefonou para a vítima?nâo
# Telefonou para a vítima?não
# Esteve no local do crime?não
# Mora perto da vítima?não
# Devia para a vítima?sim
# Já trabalhou com a vítima?sim
# Então vc é Suspeita!
# 2

# %%
#exercicio 3

#variaveis
tipo = False
gasolina = 2.5
alcool = 1.9
litros = 0
desconto = 0
valor = 0

#programa principal

tipo = False
while tipo not in {"a", "g"}: 
  tipo = input("Favor informar o tipo de combustivel. 'a' para álcool ou 'g' para gasolina: ")

flag  = False
while flag == False:
  try:
    temp = input("Favor informar a quantidade de litros: ")
    litros = float(temp)
  except ValueError:
    print ("Entrada Invalida")
  else:
    flag = True

if tipo.lower() == 'a':
  if litros > 20:
    valor = litros * alcool * 0.95
  else:
    valor = litros * alcool * 0.97
elif tipo.lower() =='g':
  if litros > 20:
    valor = litros * gasolina * 0.94
  else:
    valor = litros * gasolina * 0.96

if (valor):
  print(f'O valor a ser pago é: R$ {valor}')
else:
  print("Entrada invalida")
# Out:
# Favor informar o tipo de combustivel. 'a' para álcool ou 'g' para gasolina: a
# Favor informar a quantidade de litros: asdf
# Entrada Invalida
# Favor informar a quantidade de litros: 11ff
# Entrada Invalida
# Favor informar a quantidade de litros: 11
# passou pelo loop
# O valor a ser pago é: R$ 20.273

# %%
a = input("entre com um numero")
b = False

flag  = False
while flag == False:
  try:
    temp = input("Favor informar a quantidade de litros: ")
    litros = float(temp)
  except ValueError:
    print ("Entrada Invalida")
  else:
    flag = True
#finally:
print("acabou")
# Out:
# entre com um numero2
# Favor informar a quantidade de litros: r
# Entrada Invalida
# Favor informar a quantidade de litros: r
# Entrada Invalida
# Favor informar a quantidade de litros: f
# Entrada Invalida
# Favor informar a quantidade de litros: 3
# acabou

# %%
#Exercicio 4

import sys
import os

#variaveis
var_a = 0
var_b = 0
var_c = 0
var_delta = 0
raiz_1 = 0
raiz_2 = 0

var_a = int(input("Favor informar o valor para a variável 'a': "))

if var_a == 0:
  print('a equação não é do segundo grau')
  exit()

var_b = int(input("Favor informar o valor para a variável 'b': "))
var_c = int(input("Favor informar o valor para a variável 'c': "))

var_delta = 4 * var_a * var_c
if var_delta < 0:
  print('a equação não possui raizes reais')
elif var_delta == 0:
  raiz_1 = -0.5 * var_b / var_a 
  print(f'a equação possui apenas uma raiz:{raiz_1}')
else:
  raiz_1 = (-1 * var_b + var_delta ** 0.5 ) / 2 * var_a
  raiz_2 =  (-1 * var_b - var_delta ** 0.5 ) / 2 * var_a
  print(f'a equação possui duas raizes:{raiz_1} e {raiz_2}')

print("fim")

# %%
print('tes', end="")
print('tan', end="")
print('do')
# Out:
# testando
